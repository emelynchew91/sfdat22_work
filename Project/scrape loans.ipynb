# %%
import requests
import re

# %%
# get loans in the US

loans = []
for page in range(1, 122):
    url = "https://zip.kiva.org/loans/search_results.html?utf8=%E2%9C%93&page="+str(page)+"&query_number=2&search_text=&business_industry_id=&country_id=1&loan_state=all&order=newest"
    r = requests.get(url).text
    l = re.findall('/loans/\d+', r)
    l = [a.replace('/loans/','') for a in l]
    loans += l

loans
# Out:
# [u'18255',
#  u'18255',
#  u'18276',
#  u'18276',
#  u'18253',
#  u'18253',
#  u'18251',
#  u'18251',
#  u'18249',
#  u'18249',
#  u'18233',
#  u'18233',
#  u'18215',
#  u'18215',
#  u'18219',
#  u'18219',
#  u'18175',
#  u'18175',
#  u'18083',
#  u'18083',
#  u'18133',
#  u'18133',
#  u'18151',
#  u'18151',
#  u'18100',
#  u'18100',
#  u'18165',
#  u'18165',
#  u'18198',
#  u'18198',
#  u'18168',
#  u'18168',
#  u'18145',
#  u'18145',
#  u'18206',
#  u'18206',
#  u'18167',
#  u'18167',
#  u'18203',
#  u'18203',
#  u'18155',
#  u'18155',
#  u'18135',
#  u'18135',
#  u'18144',
#  u'18144',
#  u'18159',
#  u'18159',
#  u'18182',
#  u'18182',
#  u'18140',
#  u'18140',
#  u'18141',
#  u'18141',
#  u'18185',
#  u'18185',
#  u'18146',
#  u'18146',
#  u'18152',
#  u'18152',
#  u'17910',
#  u'17910',
#  u'18061',
#  u'18061',
#  u'18093',
#  u'18093',
#  u'18132',
#  u'18132',
#  u'17986',
#  u'17986',
#  u'18081',
#  u'18081',
#  u'18153',
#  u'18153',
#  u'17868',
#  u'17868',
#  u'17988',
#  u'17988',
#  u'18054',
#  u'18054',
#  u'17858',
#  u'17858',
#  u'18119',
#  u'18119',
#  u'18118',
#  u'18118',
#  u'18105',
#  u'18105',
#  u'18125',
#  u'18125',
#  u'18053',
#  u'18053',
#  u'18075',
#  u'18075',
#  u'18020',
#  u'18020',
#  u'18057',
#  u'18057',
#  u'18068',
#  u'18068',
#  u'18065',
#  u'18065',
#  u'18038',
#  u'18038',
#  u'17985',
#  u'17985',
#  u'18103',
#  u'18103',
#  u'17964',
#  u'17964',
#  u'18044',
#  u'18044',
#  u'17984',
#  u'17984',
#  u'18072',
#  u'18072',
#  u'17903',
#  u'17903',
#  u'18079',
#  u'18079',
#  u'17203',
#  u'17203',
#  u'17923',
#  u'17923',
#  u'18001',
#  u'18001',
#  u'18073',
#  u'18073',
#  u'17991',
#  u'17991',
#  u'17535',
#  u'17535',
#  u'18048',
#  u'18048',
#  u'17918',
#  u'17918',
#  u'18055',
#  u'18055',
#  u'18003',
#  u'18003',
#  u'18071',
#  u'18071',
#  u'18056',
#  u'18056',
#  u'17969',
#  u'17969',
#  u'18043',
#  u'18043',
#  u'18029',
#  u'18029',
#  u'18034',
#  u'18034',
#  u'18035',
#  u'18035',
#  u'17132',
#  u'17132',
#  u'18028',
#  u'18028',
#  u'18037',
#  u'18037',
#  u'18039',
#  u'18039',
#  u'18025',
#  u'18025',
#  u'18036',
#  u'18036',
#  u'17998',
#  u'17998',
#  u'17843',
#  u'17843',
#  u'17982',
#  u'17982',
#  u'18018',
#  u'18018',
#  u'17987',
#  u'17987',
#  u'17925',
#  u'17925',
#  u'17917',
#  u'17917',
#  u'17993',
#  u'17993',
#  u'17955',
#  u'17955',
#  u'17901',
#  u'17901',
#  u'17926',
#  u'17926',
#  u'17774',
#  u'17774',
#  u'17800',
#  u'17800',
#  u'18010',
#  u'18010',
#  u'17999',
#  u'17999',
#  u'17949',
#  u'17949',
#  u'17980',
#  u'17980',
#  u'17779',
#  u'17779',
#  u'17947',
#  u'17947',
#  u'17933',
#  u'17933',
#  u'17945',
#  u'17945',
#  u'17911',
#  u'17911',
#  u'17897',
#  u'17897',
#  u'17827',
#  u'17827',
#  u'17761',
#  u'17761',
#  u'17847',
#  u'17847',
#  u'17887',
#  u'17887',
#  u'17942',
#  u'17942',
#  u'17924',
#  u'17924',
#  u'17932',
#  u'17932',
#  u'17881',
#  u'17881',
#  u'17912',
#  u'17912',
#  u'17957',
#  u'17957',
#  u'17934',
#  u'17934',
#  u'17767',
#  u'17767',
#  u'17941',
#  u'17941',
#  u'17863',
#  u'17863',
#  u'17891',
#  u'17891',
#  u'17940',
#  u'17940',
#  u'17666',
#  u'17666',
#  u'17867',
#  u'17867',
#  u'17855',
#  u'17855',
#  u'17792',
#  u'17792',
#  u'17896',
#  u'17896',
#  u'17704',
#  u'17704',
#  u'17900',
#  u'17900',
#  u'17878',
#  u'17878',
#  u'17893',
#  u'17893',
#  u'17880',
#  u'17880',
#  u'17883',
#  u'17883',
#  u'17546',
#  u'17546',
#  u'17874',
#  u'17874',
#  u'17787',
#  u'17787',
#  u'17793',
#  u'17793',
#  u'17806',
#  u'17806',
#  u'17852',
#  u'17852',
#  u'17865',
#  u'17865',
#  u'17830',
#  u'17830',
#  u'17848',
#  u'17848',
#  u'17815',
#  u'17815',
#  u'17873',
#  u'17873',
#  u'17713',
#  u'17713',
#  u'17759',
#  u'17759',
#  u'17851',
#  u'17851',
#  u'17836',
#  u'17836',
#  u'17824',
#  u'17824',
#  u'17869',
#  u'17869',
#  u'17870',
#  u'17870',
#  u'17493',
#  u'17493',
#  u'17853',
#  u'17853',
#  u'17833',
#  u'17833',
#  u'17841',
#  u'17841',
#  u'17784',
#  u'17784',
#  u'17842',
#  u'17842',
#  u'17823',
#  u'17823',
#  u'17723',
#  u'17723',
#  u'17668',
#  u'17668',
#  u'17814',
#  u'17814',
#  u'17834',
#  u'17834',
#  u'17819',
#  u'17819',
#  u'17816',
#  u'17816',
#  u'17788',
#  u'17788',
#  u'17803',
#  u'17803',
#  u'17758',
#  u'17758',
#  u'17802',
#  u'17802',
#  u'17808',
#  u'17808',
#  u'17741',
#  u'17741',
#  u'17768',
#  u'17768',
#  u'17790',
#  u'17790',
#  u'17319',
#  u'17319',
#  u'17684',
#  u'17684',
#  u'17794',
#  u'17794',
#  u'17797',
#  u'17797',
#  u'17782',
#  u'17782',
#  u'17687',
#  u'17687',
#  u'17716',
#  u'17716',
#  u'17710',
#  u'17710',
#  u'17721',
#  u'17721',
#  u'17775',
#  u'17775',
#  u'17764',
#  u'17764',
#  u'17762',
#  u'17762',
#  u'17656',
#  u'17656',
#  u'17732',
#  u'17732',
#  u'17733',
#  u'17733',
#  u'17738',
#  u'17738',
#  u'17756',
#  u'17756',
#  u'17749',
#  u'17749',
#  u'17736',
#  u'17736',
#  u'17691',
#  u'17691',
#  u'17740',
#  u'17740',
#  u'17694',
#  u'17694',
#  u'17617',
#  u'17617',
#  u'17715',
#  u'17715',
#  u'17729',
#  u'17729',
#  u'17696',
#  u'17696',
#  u'17728',
#  u'17728',
#  u'17677',
#  u'17677',
#  u'17727',
#  u'17727',
#  u'17711',
#  u'17711',
#  u'17706',
#  u'17706',
#  u'17265',
#  u'17265',
#  u'17709',
#  u'17709',
#  u'17699',
#  u'17699',
#  u'17681',
#  u'17681',
#  u'17675',
#  u'17675',
#  u'17695',
#  u'17695',
#  u'17583',
#  u'17583',
#  u'17661',
#  u'17661',
#  u'17659',
#  u'17659',
#  u'17641',
#  u'17641',
#  u'17652',
#  u'17652',
#  u'17657',
#  u'17657',
#  u'17602',
#  u'17602',
#  u'17589',
#  u'17589',
#  u'17637',
#  u'17637',
#  u'17542',
#  u'17542',
#  u'17650',
#  u'17650',
#  u'17622',
#  u'17622',
#  u'17570',
#  u'17570',
#  u'17568',
#  u'17568',
#  u'17596',
#  u'17596',
#  u'17620',
#  u'17620',
#  u'17594',
#  u'17594',
#  u'17629',
#  u'17629',
#  u'17623',
#  u'17623',
#  u'17630',
#  u'17630',
#  u'17473',
#  u'17473',
#  u'17607',
#  u'17607',
#  u'17625',
#  u'17625',
#  u'17609',
#  u'17609',
#  u'17606',
#  u'17606',
#  u'17565',
#  u'17565',
#  u'17579',
#  u'17579',
#  u'17135',
#  u'17135',
#  u'17554',
#  u'17554',
#  u'17593',
#  u'17593',
#  u'17590',
#  u'17590',
#  u'17588',
#  u'17588',
#  u'17576',
#  u'17576',
#  u'17534',
#  u'17534',
#  u'17536',
#  u'17536',
#  u'17543',
#  u'17543',
#  u'17567',
#  u'17567',
#  u'17555',
#  u'17555',
#  u'17544',
#  u'17544',
#  u'17550',
#  u'17550',
#  u'17552',
#  u'17552',
#  u'17526',
#  u'17526',
#  u'17558',
#  u'17558',
#  u'17553',
#  u'17553',
#  u'17547',
#  u'17547',
#  u'17551',
#  u'17551',
#  u'17527',
#  u'17527',
#  u'17474',
#  u'17474',
#  u'17504',
#  u'17504',
#  u'17539',
#  u'17539',
#  u'17538',
#  u'17538',
#  u'17472',
#  u'17472',
#  u'17462',
#  u'17462',
#  u'17288',
#  u'17288',
#  u'17525',
#  u'17525',
#  u'17466',
#  u'17466',
#  u'17520',
#  u'17520',
#  u'17528',
#  u'17528',
#  u'17530',
#  u'17530',
#  u'17494',
#  u'17494',
#  u'17519',
#  u'17519',
#  u'17514',
#  u'17514',
#  u'17513',
#  u'17513',
#  u'17460',
#  u'17460',
#  u'17411',
#  u'17411',
#  u'17508',
#  u'17508',
#  u'17502',
#  u'17502',
#  u'17524',
#  u'17524',
#  u'17505',
#  u'17505',
#  u'17457',
#  u'17457',
#  u'17458',
#  u'17458',
#  u'17518',
#  u'17518',
#  u'17503',
#  u'17503',
#  u'17491',
#  u'17491',
#  u'17482',
#  u'17482',
#  u'17450',
#  u'17450',
#  u'17483',
#  u'17483',
#  u'17465',
#  u'17465',
#  u'17492',
#  u'17492',
#  u'17453',
#  u'17453',
#  u'17486',
#  u'17486',
#  u'17467',
#  u'17467',
#  u'17461',
#  u'17461',
#  u'17479',
#  u'17479',
#  u'17447',
#  u'17447',
#  u'17449',
#  u'17449',
#  u'17444',
#  u'17444',
#  u'17405',
#  u'17405',
#  u'17287',
#  u'17287',
#  u'17413',
#  u'17413',
#  u'17423',
#  u'17423',
#  u'17436',
#  u'17436',
#  u'17443',
#  u'17443',
#  u'17445',
#  u'17445',
#  u'17441',
#  u'17441',
#  u'17419',
#  u'17419',
#  u'17440',
#  u'17440',
#  u'17379',
#  u'17379',
#  u'17439',
#  u'17439',
#  u'17435',
#  u'17435',
#  u'17367',
#  u'17367',
#  u'16437',
#  u'16437',
#  u'17395',
#  u'17395',
#  u'17417',
#  u'17417',
#  u'17424',
#  u'17424',
#  u'17404',
#  u'17404',
#  u'17208',
#  u'17208',
#  u'17384',
#  u'17384',
#  u'17407',
#  u'17407',
#  u'17406',
#  u'17406',
#  u'17388',
#  u'17388',
#  u'17402',
#  u'17402',
#  u'17396',
#  u'17396',
#  u'17206',
#  u'17206',
#  u'17176',
#  u'17176',
#  u'17152',
#  u'17152',
#  u'17336',
#  u'17336',
#  u'17387',
#  u'17387',
#  u'17359',
#  u'17359',
#  u'17292',
#  u'17292',
#  u'17127',
#  u'17127',
#  u'17377',
#  u'17377',
#  u'17372',
#  u'17372',
#  u'17369',
#  u'17369',
#  u'17327',
#  u'17327',
#  u'17342',
#  u'17342',
#  u'17347',
#  u'17347',
#  u'17273',
#  u'17273',
#  u'17352',
#  u'17352',
#  u'17281',
#  u'17281',
#  u'17309',
#  u'17309',
#  u'17307',
#  u'17307',
#  u'17323',
#  u'17323',
#  u'17324',
#  u'17324',
#  u'17263',
#  u'17263',
#  u'17310',
#  u'17310',
#  u'17313',
#  u'17313',
#  u'17221',
#  u'17221',
#  u'17293',
#  u'17293',
#  u'17298',
#  u'17298',
#  u'17272',
#  u'17272',
#  u'17164',
#  u'17164',
#  u'17225',
#  u'17225',
#  u'17177',
#  u'17177',
#  u'17284',
#  u'17284',
#  u'17055',
#  u'17055',
#  u'17268',
#  u'17268',
#  u'17072',
#  u'17072',
#  u'17188',
#  u'17188',
#  u'17156',
#  u'17156',
#  u'17230',
#  u'17230',
#  u'17246',
#  u'17246',
#  u'17200',
#  u'17200',
#  u'17227',
#  u'17227',
#  u'17231',
#  u'17231',
#  u'17232',
#  u'17232',
#  u'17220',
#  u'17220',
#  u'17226',
#  u'17226',
#  u'17217',
#  u'17217',
#  u'17201',
#  u'17201',
#  u'17194',
#  u'17194',
#  u'17166',
#  u'17166',
#  u'17153',
#  u'17153',
#  u'17087',
#  u'17087',
#  u'17175',
#  u'17175',
#  u'17145',
#  u'17145',
#  u'17092',
#  u'17092',
#  u'17216',
#  u'17216',
#  u'17167',
#  u'17167',
#  u'17078',
#  u'17078',
#  u'17210',
#  u'17210',
#  u'17212',
#  u'17212',
#  u'17121',
#  u'17121',
#  u'17044',
#  u'17044',
#  u'17063',
#  u'17063',
#  u'17181',
#  u'17181',
#  u'17046',
#  u'17046',
#  u'17182',
#  u'17182',
#  u'17148',
#  u'17148',
#  u'17172',
#  u'17172',
#  u'17179',
#  u'17179',
#  u'17146',
#  u'17146',
#  u'17161',
#  u'17161',
#  u'17165',
#  u'17165',
#  u'16964',
#  u'16964',
#  u'17154',
#  u'17154',
#  u'17084',
#  u'17084',
#  u'17170',
#  u'17170',
#  u'17162',
#  u'17162',
#  u'17128',
#  u'17128',
#  u'17123',
#  u'17123',
#  u'17140',
#  u'17140',
#  u'17130',
#  u'17130',
#  u'17093',
#  u'17093',
#  u'17103',
#  u'17103',
#  u'17131',
#  u'17131',
#  u'17139',
#  u'17139',
#  u'17136',
#  u'17136',
#  u'17149',
#  u'17149',
#  u'17098',
#  u'17098',
#  u'16843',
#  u'16843',
#  u'17137',
#  u'17137',
#  u'17102',
#  u'17102',
#  u'17081',
#  u'17081',
#  u'17061',
#  u'17061',
#  u'16902',
#  u'16902',
#  u'17126',
#  u'17126',
#  u'17133',
#  u'17133',
#  u'17117',
#  u'17117',
#  u'17122',
#  u'17122',
#  u'17116',
#  u'17116',
#  u'17106',
#  u'17106',
#  u'17125',
#  u'17125',
#  u'17068',
#  u'17068',
#  u'17077',
#  u'17077',
#  u'10625',
#  u'10625',
#  u'17099',
#  u'17099',
#  u'17118',
#  u'17118',
#  u'16930',
#  u'16930',
#  u'17089',
#  u'17089',
#  u'17104',
#  u'17104',
#  u'17096',
#  u'17096',
#  u'17113',
#  u'17113',
#  u'17109',
#  u'17109',
#  u'16963',
#  u'16963',
#  u'16944',
#  u'16944',
#  u'17076',
#  u'17076',
#  u'17032',
#  u'17032',
#  u'17074',
#  u'17074',
#  u'17091',
#  u'17091',
#  u'17080',
#  u'17080',
#  u'16973',
#  u'16973',
#  u'16937',
#  u'16937',
#  u'17065',
#  u'17065',
#  u'17033',
#  u'17033',
#  u'17015',
#  u'17015',
#  u'17059',
#  u'17059',
#  u'17064',
#  u'17064',
#  u'17048',
#  u'17048',
#  u'17051',
#  u'17051',
#  u'17043',
#  u'17043',
#  u'17057',
#  u'17057',
#  u'17069',
#  u'17069',
#  u'16904',
#  u'16904',
#  u'17060',
#  u'17060',
#  u'16978',
#  u'16978',
#  u'16957',
#  u'16957',
#  u'17045',
#  u'17045',
#  u'17050',
#  u'17050',
#  u'16932',
#  u'16932',
#  u'16883',
#  u'16883',
#  u'17023',
#  u'17023',
#  u'17025',
#  u'17025',
#  u'16966',
#  u'16966',
#  u'17010',
#  u'17010',
#  u'17022',
#  u'17022',
#  u'17013',
#  u'17013',
#  u'16911',
#  u'16911',
#  u'17011',
#  u'17011',
#  u'17007',
#  u'17007',
#  u'16970',
#  u'16970',
#  u'17005',
#  u'17005',
#  u'16688',
#  u'16688',
#  u'16975',
#  u'16975',
#  u'16939',
#  u'16939',
#  u'17003',
#  u'17003',
#  u'16942',
#  u'16942',
#  u'16941',
#  u'16941',
#  u'17001',
#  u'17001',
#  u'16976',
#  u'16976',
#  u'16977',
#  u'16977',
#  u'16958',
#  u'16958',
#  u'16969',
#  u'16969',
#  u'16876',
#  u'16876',
#  u'16921',
#  u'16921',
#  u'16915',
#  u'16915',
#  u'16946',
#  u'16946',
#  u'16866',
#  u'16866',
#  u'16907',
#  u'16907',
#  u'16952',
#  u'16952',
#  u'16898',
#  u'16898',
#  u'16913',
#  u'16913',
#  u'16929',
#  u'16929',
#  u'16918',
#  u'16918',
#  u'16927',
#  u'16927',
#  u'16853',
#  u'16853',
#  u'16943',
#  u'16943',
#  u'16885',
#  u'16885',
#  u'16834',
#  u'16834',
#  u'16940',
#  u'16940',
#  u'16924',
#  u'16924',
#  ...]

# %%
loans = list(set(loans))
len(loans)

#2415 loans in the U.S.
# Out:
# 2415

# %%
# scrape characteristics of loans

import sys
import numpy as np
sys.path = ['', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/distribute-0.6.14-py2.7.egg', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pip-8.0.0.dev0-py2.7.egg', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pytz-2015.7-py2.7.egg', '/Library/Python/2.7/site-packages/pandas-0.14.1-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/distribute-0.6.49-py2.7.egg', '/Library/Python/2.7/site-packages/BeautifulSoup-3.2.1-py2.7.egg', '/Library/Python/2.7/site-packages/mechanize-0.2.5-py2.7.egg', '/Library/Python/2.7/site-packages/pyPdf-1.13-py2.7.egg', '/Library/Python/2.7/site-packages/rapportive-0.1.0-py2.7.egg', '/Library/Python/2.7/site-packages/docopt-0.6.1-py2.7.egg', '/Library/Python/2.7/site-packages/django_registration-1.0-py2.7.egg', '/Library/Python/2.7/site-packages/MySQL_python-1.2.4b4-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/openpyxl-1.8.4-py2.7.egg', '/Library/Python/2.7/site-packages/django_chartit-0.1-py2.7.egg', '/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python', '/Library/Python/2.7/site-packages/gnureadline-6.3.3-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/pymorph-0.96-py2.7.egg', '/Library/Python/2.7/site-packages/webcolors-1.4-py2.7.egg', '/Library/Python/2.7/site-packages/virtualenv-1.11.5-py2.7.egg', '/Library/Python/2.7/site-packages/python_openid-2.2.5-py2.7.egg', '/Library/Python/2.7/site-packages/httplib2-0.9-py2.7.egg', '/Library/Python/2.7/site-packages/oauth-1.0.1-py2.7.egg', '/Library/Python/2.7/site-packages/textblob-0.8.4-py2.7.egg', '/Library/Python/2.7/site-packages/PyYAML-3.11-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/feedparser-5.1.3-py2.7.egg', '/Library/Python/2.7/site-packages/pyThesaurus-1.1_dev_r371-py2.7.egg', '/Library/Python/2.7/site-packages/KISSmetrics-0.1.0-py2.7.egg', '/Library/Python/2.7/site-packages/simplejson-3.6.0-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/dnspython-1.12.0-py2.7.egg', '/Library/Python/2.7/site-packages/RapLeafApi-0.1.1-py2.7.egg', '/Library/Python/2.7/site-packages/statsmodels-0.6.0-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/patsy-0.3.0-py2.7.egg', '/Library/Python/2.7/site-packages/paramiko-1.15.1-py2.7.egg', '/Library/Python/2.7/site-packages/ecdsa-0.11-py2.7.egg', '/Library/Python/2.7/site-packages/pycrypto-2.6.1-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/postgres-2.1.2-py2.7.egg', '/Library/Python/2.7/site-packages/guppy-0.1.10-py2.7-macosx-10.9-intel.egg', '/Library/Python/2.7/site-packages/PyBrain-0.3-py2.7.egg', '/Library/Python/2.7/site-packages/Flask-0.10.1-py2.7.egg', '/Library/Python/2.7/site-packages/itsdangerous-0.24-py2.7.egg', '/Library/Python/2.7/site-packages/Werkzeug-0.9.6-py2.7.egg', '/Library/Python/2.7/site-packages/clearbit-0.0.7-py2.7.egg', '/Library/Python/2.7/site-packages/fuzzywuzzy-0.5.0-py2.7.egg', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python27.zip', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/plat-darwin', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/plat-mac', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/plat-mac/lib-scriptpackages', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/lib-tk', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/lib-old', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/lib-dynload', '/Users/sinanozdemir/Library/Python/2.7/lib/python/site-packages', '/usr/local/lib/python2.7/site-packages', '/usr/local/Cellar/scapy/2.3.1/libexec/vendor/lib/python2.7/site-packages', '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages', '/Library/Python/2.7/site-packages', '/Library/Python/2.7/site-packages/setuptools-0.6c11-py2.7.egg-info']
from bs4 import BeautifulSoup 
import pandas as pd
datasets = []
for index, url in enumerate(loans):
    if index % 20 == 0:
        print index
    r = requests.get('https://zip.kiva.org/loans/'+str(url))
    if r.status_code != 200: break
    if 'Sorry, We Could Not Find That Page' in r.text:
        print "no page"
    if 'Log in through a Kiva.org account' in r.text: 
        print "HAVE TO LOG IN"
        url = url + 1 
        continue

    dataset = {}
    b = BeautifulSoup(r.text, 'html.parser') 
    b.prettify() # will print the html nicely
    try:
        dataset["city"] = b.findAll('h3')[0].text
    except:
        dataset["city"] = None
    try:
        dataset["status"] = b.findAll('div', attrs ={'class': 'grid_4 omega'})[0].find('div', attrs={'class':'state'}).text.strip()
    except:
        dataset["status"] = None
    try:
        a = re.findall('\d+',b.findAll('div', attrs ={'class': 'grid_4 omega'})[0].find('p').text.strip())
        if len(a) > 1:
            dataset["size"] = re.findall('\d+',b.findAll('div', attrs ={'class': 'grid_4 omega'})[0].find('p').text.strip())[0] + re.findall('\d+',b.findAll('div', attrs ={'class': 'grid_4 omega'})[0].find('p').text.strip())[1]
        else:
            dataset["size"] = re.findall('\d+',b.findAll('div', attrs ={'class': 'grid_4 omega'})[0].find('p').text.strip())[0]
    except:
        dataset["size"] = None
    try:
        dataset["business_name"]= b.findAll('h2')[0].text.strip()
    except:
        dataset["business_name"] = None
    try:
        dataset["term"] = re.findall('\d+', b.findAll('dd')[0].text)[0]
    except:
        dataset["term"] = None
    try:
        dataset["industry"] = b.findAll('dl', attrs={'class':'summary'})[1].findChildren('dd')[0].text.strip()
    except:
        dataset["industry"] = None
    try:
        dataset["years_experience"] = b.findAll('dl', attrs={'class':'summary'})[1].findChildren('dd')[1].text.strip()
    except:
        dataset["years_experience"] = None
    try:
        dataset["loan_id"] = re.findall('\d+', str(b.findAll('form')))[0]
    except:
        dataset["loan_id"] = None
    try:
        dataset["personal_story"] = b.findAll('div', attrs = {'class': 'question_answer'})[0].text.strip().replace('Personal Story ','')
    except:
        dataset["personal_story"] = None
    try:
        dataset["business_description"] = b.findAll('div', attrs = {'class': 'question_answer'})[1].text.strip()
    except:
        dataset["business_description"] = None
    try:
        dataset["loan_purpose"] = b.findAll('div', attrs = {'class': 'question_answer'})[2].text.strip()
    except:
        dataset["loan_purpose"] = None
    try:
        dataset["listed"] = re.findall('\d+-\d+-\d+',str(b.findAll('dd')[2]))[0]
    except:
        dataset["listed"] = None
    try:
        dataset["disbursed"] = re.findall('\d+-\d+-\d+',str(b.findAll('dd')[3]))[0]
    except:
        dataset["disbursed"] = None
    try:
        dataset["conversations"] = int(b.findAll('div', attrs ={'class': 'grid_8 alpha'})[0].find('div', attrs={'class':'comments_count count'}).text.strip())
    except:
        dataset["conversations"] = None
    try:
        dataset["total_lenders"] = re.findall('\d+', str(b.findAll('div', attrs = {'class':'counts clearfix'})))[0]
        l = b.find('div', attrs = {'class':'counts clearfix'}).text.strip().split(',')
        if len(l) > 1:
            dataset["invited_lenders"] = int(re.findall('\d+', l[1].strip())[0])
        else:
            dataset["invited_lenders"] = 0
    except:
        dataset["invited_lenders"] = 0
        
    try:
        dataset["trustee"] =  b.findAll('div', attrs={'class':'loan_trustee box box_round'})[0].find('div', attrs={'class':'who'}).text
    except:
        dataset["trustee"] = None

        
    datasets.append(dataset)
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400

# %%
re.findall('\d+',b.findAll('div', attrs ={'class': 'grid_4 omega'})[0].find('p').text.strip())[0]
# Out:
# u'1'

# %%
kiva.head()
# Out:
#                                 business_description  \
# 0  Business Description\nWe started Trinity Farm ...
# 1  Business Description\nDistrict2.Co is a Virtua...
# 2  Business Description\nI am a sole proprietor, ...
# 3  Business Description\nI started 4 years ago as...
# 4  Business Description\nWalnut Way Conservation ...
#
#                          business_name              city  conversations  \
# 0                         Trinity Farm   Clintondale, NY           12.0
# 1                         District2.Co   Los Angeles, CA           14.0
# 2             Maryland Pet Acupuncture  College Park, MD           12.0
# 3                   BellaLola Boutique      Houston,, TX           97.0
# 4  Walnut Way - Blue Skies Landscaping     Milwaukee, WI           13.0
#
#     disbursed                    industry  invited_lenders      listed  \
# 0  2014-07-01                 Agriculture               18  2014-05-12
# 1  2014-06-29                  Technology                8  2014-06-12
# 2  2014-06-25                       Other               34  2014-06-04
# 3  2016-04-08               Arts / Crafts               16  2016-02-04
# 4  2015-03-10  Lawn / Landscaping service                5  2015-02-16
#
#   loan_id                                       loan_purpose  \
# 0    4022  What is the purpose of this loan?\nWe are seek...
# 1    4023  What is the purpose of this loan?\n$500 Youth ...
# 2    4020  What is the purpose of this loan?\nThe loan wo...
# 3   17525  What is the purpose of this loan?\nI will be b...
# 4   11384  What is the purpose of this loan?\nLoan will b...
#
#                                       personal_story  size       status term  \
# 0  Personal Story\nI've been a farmer all my life...  5000  PAYING BACK   24
# 1  Personal Story\nI was born in Inglewood, CA an...   500        ENDED   24
# 2  Personal Story\nI grew up in a small town in t...  5000  PAYING BACK   24
# 3  Personal Story\nI have live all my life in Hou...  4250  PAYING BACK   24
# 4  Personal Story\nLarry and Sharon, who co-found...  8000  PAYING BACK   36
#
#   total_lenders                                           trustee  \
# 0           303                                  Karen Washington
# 1            19  Vermont Slauson Economic Development Corporation
# 2            99                                  The Big Bad Woof
# 3            79                                Borrowers Network
# 4           213  Milwaukee Community Business Collaborative, Inc.
#
#     years_experience
# 0  More than 5 years
# 1  6 months - 1 year
# 2  More than 5 years
# 3  3 years - 5 years
# 4  3 years - 5 years

# %%
kiva.shape
# Out:
# (2415, 17)

# %%
kiva.columns
# Out:
# Index([u'business_description', u'business_name', u'city', u'conversations',
#        u'disbursed', u'industry', u'invited_lenders', u'listed', u'loan_id',
#        u'loan_purpose', u'personal_story', u'size', u'status', u'term',
#        u'total_lenders', u'trustee', u'years_experience'],
#       dtype='object')

# %%
''' #r = requests.get('https://zip.kiva.org/loans/'+str(url))
   # if index % 100 == 0:
     #   print "SAVING AT", index
import pandas as pd
kiva = pd.DataFrame(datasets)
#kiva.to_csv('kiva_total.csv', encoding='utf-8')
kiva['length'] = (pd.to_datetime(kiva['disbursed']) - pd.to_datetime(kiva['listed'])).apply(lambda x:x.days)
kiva'''
